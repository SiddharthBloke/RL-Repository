# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddharthBloke/RL-Repository/blob/main/correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed()

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0,50,1000)
y = np.random.randint(0,50,1000)

# %%
x
# Out:
# array([44, 11, 23,  1, 31, 12,  8,  1, 41, 32, 34, 34, 41, 33, 39, 21, 24,
#         7, 32, 37,  0, 17,  6, 47,  3,  6, 16, 38, 37, 12, 10, 28, 43,  6,
#        18, 46, 39, 26, 44, 39, 46, 35, 22, 33, 12, 44, 24, 23, 17,  0, 34,
#        16,  3, 42, 48, 41, 14,  7, 21, 39,  3, 16, 22, 11, 39, 45, 30,  6,
#        17,  1, 48, 11,  5, 43,  6, 23, 15, 44, 17, 33, 20, 21,  7,  8,  3,
#        30, 47,  3, 22, 24, 46, 39, 35, 10, 40, 45,  2, 25, 35, 28, 18, 43,
#        32, 16, 10,  6,  4, 27, 46, 47, 24,  9, 42, 41,  1, 12, 16,  7, 26,
#        14, 16, 46, 28, 28, 45, 12,  1, 49,  9, 19, 28, 42, 12, 25, 30, 22,
#        44, 32, 27, 25, 11,  5, 26, 49, 23, 39, 43, 12, 16,  6,  3,  6, 16,
#        47, 44, 10,  2, 48, 42,  2, 40,  4, 18, 38, 39, 17, 21, 45, 44,  4,
#        19, 17, 24, 25, 31,  8, 40, 32, 32, 33, 41, 18, 45, 15, 17, 37,  8,
#        12,  3, 21,  7,  7, 40, 26, 33,  3, 31, 38, 39, 34,  5, 14, 32, 37,
# ...

# %%
y
# Out:
# array([37, 48, 49,  1, 17, 44,  6, 42, 23, 48, 12, 23, 22, 35, 25, 48, 26,
#        18, 43, 11, 30,  7, 23, 22, 48, 25, 20,  4, 25, 45,  9, 14,  8, 18,
#        31, 31,  4, 39, 22, 36, 45,  2, 21, 34, 37, 46, 15, 35, 43, 12, 14,
#        43, 34,  9, 17, 31, 36,  4,  2, 37, 49, 40, 42, 12, 16, 21, 17, 19,
#        28, 34, 20, 22,  1, 48,  4,  1,  9, 24, 22, 29, 30,  7, 49, 20, 29,
#         4, 11, 40, 43, 19, 23, 46, 36, 24, 42, 24, 46,  6, 14, 36, 30,  4,
#        27,  4, 25, 29, 43,  8, 42, 29,  8, 13, 10, 39, 42, 24, 44,  6, 49,
#        45, 35, 49, 47, 44, 13, 39, 17, 13, 23, 11, 17,  7, 45, 20, 37, 22,
#        22, 48, 43,  9, 42, 33, 13, 19, 10, 28,  6, 49, 22, 12,  3, 36, 39,
#        12, 43, 28, 24,  8,  6, 30, 36, 33, 37, 32,  6, 33, 46, 48, 14, 11,
#        12,  7, 29, 14, 23,  0, 38, 31, 29, 20, 28, 40, 18, 32, 14, 28, 34,
#        27,  8, 32, 29, 31,  3, 12,  0, 28,  9, 44,  0, 30, 32, 11, 18, 24,
# ...

# %%
# Positive correlation with some noise
y = x + np.random.normal(0, 50, 1000)
y
# Out:
# array([ 4.37784716e+01,  6.72093826e+01,  9.26776555e+01,  4.67521346e+01,
#        -3.33411203e+00, -1.42581784e+00, -4.12668258e+00,  5.90444979e+01,
#         1.00452476e+02,  6.81441307e+00,  1.20029331e+02, -1.72237018e+01,
#         6.75699033e+01,  1.00983415e+02,  8.22991029e+01, -4.71565557e+01,
#        -2.05530922e+00, -1.09138790e+00,  3.88781448e+01,  7.47056269e+01,
#        -5.80803282e+01,  3.37763228e+01,  5.02791588e+01,  6.94672632e+00,
#         7.96000051e+01,  1.02104318e+01,  4.48774232e+01,  1.38555163e+01,
#         2.18267422e+01,  3.12829999e+01, -1.26355172e+02,  2.26880012e+01,
#         5.20906893e+01,  1.28088713e+01, -2.53695784e+01,  1.11391782e+02,
#         7.09381295e+01, -1.28799421e+01, -1.95020159e+01,  6.89809890e+01,
#         6.23841846e+01,  6.58308965e+01,  2.99683797e+01,  6.03184954e+00,
#         6.70794400e+01,  1.15204008e+01, -6.14199868e+01, -1.89923185e+01,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.30021674],
#        [0.30021674, 1.        ]])

# %%
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use("ggplot")

plt.scatter(x,y)
plt.show()

# %% [markdown]
# For Negative Correlation

# %%
x = np.random.randint(0,50,1000)
y = 100 - x + np.random.normal(0,5,1000)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94219204],
#        [-0.94219204,  1.        ]])

# %%
plt.scatter(x,y)
plt.show()

# %%
x = np.random.randint(0,50,1000)
y = np.random.randint(0,50,1000)

np.corrcoef(x,y)
# Out:
# array([[1.        , 0.01408667],
#        [0.01408667, 1.        ]])

# %%
plt.scatter(x,y)
plt.xlabel('Values of X --->')
plt.ylabel('Values of Y --->')
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'a': np.random.randint(0,50,1000)}) 
df['b'] = df['a'] + np.random.normal(0,10,1000) 
df['c'] = 100 - df['a'] + np.random.randint(0,5,1000) 
df['d'] = np.random.randint(0,50,1000) 
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.830320 -0.994902  0.001803
# b  0.830320  1.000000 -0.824786 -0.011283
# c -0.994902 -0.824786  1.000000 -0.000969
# d  0.001803 -0.011283 -0.000969  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize = (10,10))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
